# %% [markdown]
# # MWPM

# %%
import sinter
import stim
import matplotlib.pyplot as plt
from typing import List

# %%
import os

surface_code_tasks = [
    sinter.Task(
        circuit = stim.Circuit.generated(
            "surface_code:rotated_memory_z",
            rounds=d * 3,
            distance=d,
            after_clifford_depolarization=noise,
            after_reset_flip_probability=noise,
            before_measure_flip_probability=noise,
            before_round_data_depolarization=noise,
        ),
        json_metadata={'d': d, 'r': d * 3, 'p': noise},
    )
    for d in [3, 5, 7]
    for noise in [0.008, 0.009, 0.01, 0.011, 0.012]
]

collected_surface_code_stats: List[sinter.TaskStats] = sinter.collect(
    num_workers=os.cpu_count(),
    tasks=surface_code_tasks,
    decoders=['pymatching'],
    max_shots=1_000_000,
    max_errors=5_000,
    print_progress=True,
)
# Out:
# Starting 18 workers...
# 15 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         1 pymatching   ?    1000000        5000 d=3,r=9,p=0.008
#         1 pymatching <1m     998703        4841 d=3,r=9,p=0.009
#         1 pymatching   ?    1000000        5000 d=3,r=9,p=0.01
#         1 pymatching   ?    1000000        5000 d=3,r=9,p=0.011
#         1 pymatching   ?    1000000        5000 d=3,r=9,p=0.012
#         1 pymatching   ?    1000000        5000 d=5,r=15,p=0.008
#         1 pymatching   ?    1000000        5000 d=5,r=15,p=0.009
#         1 pymatching   ?    1000000        5000 d=5,r=15,p=0.01
#         1 pymatching   ?    1000000        5000 d=5,r=15,p=0.011
#         1 pymatching   ?    1000000        5000 d=5,r=15,p=0.012
#         1 pymatching   ?    1000000        5000 d=7,r=21,p=0.008
#         1 pymatching   ?    1000000        5000 d=7,r=21,p=0.009
#         2 pymatching   ?    1000000        5000 d=7,r=21,p=0.01
#         2 pymatching   ?    1000000        5000 d=7,r=21,p=0.011
#         2 pymatching   ?    1000000        5000 d=7,r=21,p=0.012
# 15 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         1 pymatching   ?    1000000        5000 d=3,r=9,p=0.008
#         1 pymatching <1m     975151        1875 d=3,r=9,p=0.009
#         1 pymatching   ?    1000000        5000 d=3,r=9,p=0.01
#         1 pymatching <1m     986415        2650 d=3,r=9,p=0.011
#         1 pymatching   ?    1000000        5000 d=3,r=9,p=0.012
#         1 pymatching <1m     998703        4823 d=5,r=15,p=0.008
#         1 pymatching   ?    1000000        5000 d=5,r=15,p=0.009
#         1 pymatching <1m     997679        4475 d=5,r=15,p=0.01
#         1 pymatching   ?    1000000        5000 d=5,r=15,p=0.011
#         1 pymatching   ?    1000000        5000 d=5,r=15,p=0.012
#         1 pymatching   ?    1000000        5000 d=7,r=21,p=0.008
#         1 pymatching   ?    1000000        5000 d=7,r=21,p=0.009
#         2 pymatching   ?    1000000        5000 d=7,r=21,p=0.01
#         2 pymatching <1m     999983        4993 d=7,r=21,p=0.011
#         2 pymatching   ?    1000000        5000 d=7,r=21,p=0.012
# 14 tasks left:
#   workers    decoder        eta shots_left errors_left json_metadata
#         2 pymatching          ?    1000000        5000 d=3,r=9,p=0.008
#         1 pymatching          ?    1000000        5000 d=3,r=9,p=0.01
#         1 pymatching [draining]     971055         -88 d=3,r=9,p=0.011
#         1 pymatching          ?    1000000        5000 d=3,r=9,p=0.012
#         1 pymatching        <1m     997679        4663 d=5,r=15,p=0.008
#         1 pymatching          ?    1000000        5000 d=5,r=15,p=0.009
#         1 pymatching        <1m     995631        4020 d=5,r=15,p=0.01
#         1 pymatching          ?    1000000        5000 d=5,r=15,p=0.011
#         1 pymatching          ?    1000000        5000 d=5,r=15,p=0.012
#         1 pymatching          ?    1000000        5000 d=7,r=21,p=0.008
#         1 pymatching          ?    1000000        5000 d=7,r=21,p=0.009
#         2 pymatching          ?    1000000        5000 d=7,r=21,p=0.01
#         2 pymatching        <1m     999727        4899 d=7,r=21,p=0.011
#         2 pymatching          ?    1000000        5000 d=7,r=21,p=0.012
# 13 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         2 pymatching   ?    1000000        5000 d=3,r=9,p=0.008
#         2 pymatching   ?    1000000        5000 d=3,r=9,p=0.01
#         1 pymatching   ?    1000000        5000 d=3,r=9,p=0.012
#         1 pymatching <1m     996655        4502 d=5,r=15,p=0.008
#         1 pymatching   ?    1000000        5000 d=5,r=15,p=0.009
#         1 pymatching <1m     993583        3576 d=5,r=15,p=0.01
#         1 pymatching   ?    1000000        5000 d=5,r=15,p=0.011
#         1 pymatching <1m     999727        4920 d=5,r=15,p=0.012
#         1 pymatching   ?    1000000        5000 d=7,r=21,p=0.008
#         1 pymatching   ?    1000000        5000 d=7,r=21,p=0.009
#         2 pymatching <1m     999727        4921 d=7,r=21,p=0.01
#         2 pymatching <1m     999727        4899 d=7,r=21,p=0.011
#         2 pymatching   ?    1000000        5000 d=7,r=21,p=0.012
# 13 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         2 pymatching   ?    1000000        5000 d=3,r=9,p=0.008
#         2 pymatching   ?    1000000        5000 d=3,r=9,p=0.01
#         1 pymatching   ?    1000000        5000 d=3,r=9,p=0.012
#         1 pymatching <1m     991535        3734 d=5,r=15,p=0.008
#         1 pymatching   ?    1000000        5000 d=5,r=15,p=0.009
#         1 pymatching <1m     991535        3100 d=5,r=15,p=0.01
#         1 pymatching   ?    1000000        5000 d=5,r=15,p=0.011
#         1 pymatching <1m     997679        4322 d=5,r=15,p=0.012
#         1 pymatching   ?    1000000        5000 d=7,r=21,p=0.008
#         1 pymatching   ?    1000000        5000 d=7,r=21,p=0.009
#         2 pymatching <1m     999727        4921 d=7,r=21,p=0.01
#         2 pymatching <1m     998703        4581 d=7,r=21,p=0.011
#         2 pymatching   ?    1000000        5000 d=7,r=21,p=0.012
# 13 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         2 pymatching   ?    1000000        5000 d=3,r=9,p=0.008
#         2 pymatching   ?    1000000        5000 d=3,r=9,p=0.01
#         1 pymatching   ?    1000000        5000 d=3,r=9,p=0.012
#         1 pymatching <1m     987439        3182 d=5,r=15,p=0.008
#         1 pymatching   ?    1000000        5000 d=5,r=15,p=0.009
#         1 pymatching <1m     988463        2447 d=5,r=15,p=0.01
#         1 pymatching   ?    1000000        5000 d=5,r=15,p=0.011
#         1 pymatching <1m     995631        3763 d=5,r=15,p=0.012
#         1 pymatching   ?    1000000        5000 d=7,r=21,p=0.008
#         1 pymatching <1m     999727        4943 d=7,r=21,p=0.009
#         2 pymatching <1m     998703        4643 d=7,r=21,p=0.01
#         2 pymatching <1m     997679        4257 d=7,r=21,p=0.011
#         2 pymatching   ?    1000000        5000 d=7,r=21,p=0.012
# 13 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         2 pymatching   ?    1000000        5000 d=3,r=9,p=0.008
#         2 pymatching   ?    1000000        5000 d=3,r=9,p=0.01
#         1 pymatching   ?    1000000        5000 d=3,r=9,p=0.012
#         1 pymatching <1m     987439        3182 d=5,r=15,p=0.008
#         1 pymatching   ?    1000000        5000 d=5,r=15,p=0.009
#         1 pymatching <1m     988463        2447 d=5,r=15,p=0.01
#         1 pymatching   ?    1000000        5000 d=5,r=15,p=0.011
#         1 pymatching <1m     993583        3135 d=5,r=15,p=0.012
#         1 pymatching   ?    1000000        5000 d=7,r=21,p=0.008
#         1 pymatching <1m     998703        4705 d=7,r=21,p=0.009
#         2 pymatching <1m     997679        4382 d=7,r=21,p=0.01
#         2 pymatching <1m     997679        4257 d=7,r=21,p=0.011
#         2 pymatching   ?    1000000        5000 d=7,r=21,p=0.012
# 13 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         2 pymatching <1m     967710        1562 d=3,r=9,p=0.008
#         2 pymatching   ?    1000000        5000 d=3,r=9,p=0.01
#         1 pymatching   ?    1000000        5000 d=3,r=9,p=0.012
#         1 pymatching <1m     981295        2307 d=5,r=15,p=0.008
#         1 pymatching <1m     998703        4777 d=5,r=15,p=0.009
#         1 pymatching <1m     984367        1576 d=5,r=15,p=0.01
#         1 pymatching   ?    1000000        5000 d=5,r=15,p=0.011
#         1 pymatching <1m     993583        3135 d=5,r=15,p=0.012
#         1 pymatching   ?    1000000        5000 d=7,r=21,p=0.008
#         1 pymatching <1m     998703        4705 d=7,r=21,p=0.009
#         2 pymatching <1m     997679        4382 d=7,r=21,p=0.01
#         2 pymatching <1m     996655        3934 d=7,r=21,p=0.011
#         2 pymatching   ?    1000000        5000 d=7,r=21,p=0.012
# 12 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         2 pymatching   ?    1000000        5000 d=3,r=9,p=0.01
#         2 pymatching   ?    1000000        5000 d=3,r=9,p=0.012
#         2 pymatching <1m     981294        2307 d=5,r=15,p=0.008
#         1 pymatching <1m     995631        4248 d=5,r=15,p=0.009
#         1 pymatching <1m     984367        1576 d=5,r=15,p=0.01
#         1 pymatching <1m     998703        4646 d=5,r=15,p=0.011
#         1 pymatching <1m     991535        2493 d=5,r=15,p=0.012
#         1 pymatching   ?    1000000        5000 d=7,r=21,p=0.008
#         1 pymatching <1m     997679        4481 d=7,r=21,p=0.009
#         2 pymatching <1m     996655        4115 d=7,r=21,p=0.01
#         2 pymatching <1m     996655        3934 d=7,r=21,p=0.011
#         2 pymatching   ?    1000000        5000 d=7,r=21,p=0.012
# 12 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         2 pymatching   ?    1000000        5000 d=3,r=9,p=0.01
#         2 pymatching <1m     997406        4502 d=3,r=9,p=0.012
#         2 pymatching <1m     979998        2136 d=5,r=15,p=0.008
#         1 pymatching <1m     994607        4061 d=5,r=15,p=0.009
#         1 pymatching <1m     980271         660 d=5,r=15,p=0.01
#         1 pymatching <1m     997679        4385 d=5,r=15,p=0.011
#         1 pymatching <1m     991535        2493 d=5,r=15,p=0.012
#         1 pymatching   ?    1000000        5000 d=7,r=21,p=0.008
#         1 pymatching <1m     996655        4266 d=7,r=21,p=0.009
#         2 pymatching <1m     995631        3828 d=7,r=21,p=0.01
#         2 pymatching <1m     996655        3934 d=7,r=21,p=0.011
#         2 pymatching   ?    1000000        5000 d=7,r=21,p=0.012
# 12 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         2 pymatching <1m     997406        4601 d=3,r=9,p=0.01
#         2 pymatching <1m     989214        2891 d=3,r=9,p=0.012
#         2 pymatching <1m     972830        1102 d=5,r=15,p=0.008
#         1 pymatching <1m     994607        4061 d=5,r=15,p=0.009
#         1 pymatching <1m     980271         660 d=5,r=15,p=0.01
#         1 pymatching <1m     996655        4097 d=5,r=15,p=0.011
#         1 pymatching <1m     989487        1880 d=5,r=15,p=0.012
#         1 pymatching   ?    1000000        5000 d=7,r=21,p=0.008
#         1 pymatching <1m     996655        4266 d=7,r=21,p=0.009
#         2 pymatching <1m     995631        3828 d=7,r=21,p=0.01
#         2 pymatching <1m     996655        3934 d=7,r=21,p=0.011
#         2 pymatching <1m     999999        4999 d=7,r=21,p=0.012
# 12 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         2 pymatching <1m     987166        3070 d=3,r=9,p=0.01
#         2 pymatching <1m     979998        1117 d=3,r=9,p=0.012
#         2 pymatching <1m     972830        1102 d=5,r=15,p=0.008
#         1 pymatching <1m     993583        3873 d=5,r=15,p=0.009
#         1 pymatching <1m     980271         660 d=5,r=15,p=0.01
#         1 pymatching <1m     996655        4097 d=5,r=15,p=0.011
#         1 pymatching <1m     989487        1880 d=5,r=15,p=0.012
#         1 pymatching   ?    1000000        5000 d=7,r=21,p=0.008
#         1 pymatching <1m     996655        4266 d=7,r=21,p=0.009
#         2 pymatching <1m     995631        3828 d=7,r=21,p=0.01
#         2 pymatching <1m     995630        3594 d=7,r=21,p=0.011
#         2 pymatching <1m     999983        4996 d=7,r=21,p=0.012
# 12 tasks left:
#   workers    decoder        eta shots_left errors_left json_metadata
#         2 pymatching        <1m     978974        1819 d=3,r=9,p=0.01
#         2 pymatching [draining]     967710       -1287 d=3,r=9,p=0.012
#         2 pymatching        <1m     971806         940 d=5,r=15,p=0.008
#         1 pymatching        <1m     993583        3873 d=5,r=15,p=0.009
#         1 pymatching        <1m     978223         201 d=5,r=15,p=0.01
#         1 pymatching        <1m     995631        3841 d=5,r=15,p=0.011
#         1 pymatching        <1m     989487        1880 d=5,r=15,p=0.012
#         1 pymatching         1m     999999        4999 d=7,r=21,p=0.008
#         1 pymatching        <1m     996655        4266 d=7,r=21,p=0.009
#         2 pymatching        <1m     994607        3556 d=7,r=21,p=0.01
#         2 pymatching        <1m     995630        3594 d=7,r=21,p=0.011
#         2 pymatching        <1m     999983        4996 d=7,r=21,p=0.012
# 11 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         2 pymatching <1m     971806         727 d=3,r=9,p=0.01
#         2 pymatching <1m     967710         390 d=5,r=15,p=0.008
#         2 pymatching <1m     991535        3506 d=5,r=15,p=0.009
#         2 pymatching <1m     978223         201 d=5,r=15,p=0.01
#         1 pymatching <1m     995631        3841 d=5,r=15,p=0.011
#         1 pymatching <1m     987439        1273 d=5,r=15,p=0.012
#         1 pymatching  1m     999983        4998 d=7,r=21,p=0.008
#         1 pymatching <1m     996655        4266 d=7,r=21,p=0.009
#         2 pymatching <1m     994590        3554 d=7,r=21,p=0.01
#         2 pymatching <1m     995358        3490 d=7,r=21,p=0.011
#         2 pymatching <1m     999727        4898 d=7,r=21,p=0.012
# 9 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         2 pymatching <1m     966686         266 d=5,r=15,p=0.008
#         2 pymatching <1m     991262        3470 d=5,r=15,p=0.009
#         2 pymatching <1m     994607        3584 d=5,r=15,p=0.011
#         2 pymatching <1m     987439        1273 d=5,r=15,p=0.012
#         2 pymatching <1m     999727        4966 d=7,r=21,p=0.008
#         2 pymatching <1m     995631        4048 d=7,r=21,p=0.009
#         2 pymatching <1m     994334        3483 d=7,r=21,p=0.01
#         2 pymatching <1m     995358        3490 d=7,r=21,p=0.011
#         2 pymatching <1m     999727        4898 d=7,r=21,p=0.012
# 9 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         2 pymatching <1m     965662         117 d=5,r=15,p=0.008
#         2 pymatching <1m     988190        2931 d=5,r=15,p=0.009
#         2 pymatching <1m     994590        3578 d=5,r=15,p=0.011
#         2 pymatching <1m     987166        1196 d=5,r=15,p=0.012
#         2 pymatching <1m     999727        4966 d=7,r=21,p=0.008
#         2 pymatching <1m     995631        4048 d=7,r=21,p=0.009
#         2 pymatching <1m     994334        3483 d=7,r=21,p=0.01
#         2 pymatching <1m     995358        3490 d=7,r=21,p=0.011
#         2 pymatching <1m     999727        4898 d=7,r=21,p=0.012
# 9 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         2 pymatching <1m     965662         117 d=5,r=15,p=0.008
#         2 pymatching <1m     988190        2931 d=5,r=15,p=0.009
#         2 pymatching <1m     993310        3246 d=5,r=15,p=0.011
#         2 pymatching <1m     987166        1196 d=5,r=15,p=0.012
#         2 pymatching <1m     999727        4966 d=7,r=21,p=0.008
#         2 pymatching <1m     995631        4048 d=7,r=21,p=0.009
#         2 pymatching <1m     994334        3483 d=7,r=21,p=0.01
#         2 pymatching <1m     994846        3317 d=7,r=21,p=0.011
#         2 pymatching <1m     999198        4700 d=7,r=21,p=0.012
# 9 tasks left:
#   workers    decoder        eta shots_left errors_left json_metadata
#         2 pymatching [draining]     959518        -737 d=5,r=15,p=0.008
#         2 pymatching        <1m     985118        2367 d=5,r=15,p=0.009
#         2 pymatching        <1m     992286        2984 d=5,r=15,p=0.011
#         2 pymatching        <1m     984094         247 d=5,r=15,p=0.012
#         2 pymatching        <1m     999727        4966 d=7,r=21,p=0.008
#         2 pymatching        <1m     995631        4048 d=7,r=21,p=0.009
#         2 pymatching        <1m     993822        3332 d=7,r=21,p=0.01
#         2 pymatching        <1m     993822        2967 d=7,r=21,p=0.011
#         2 pymatching        <1m     998942        4597 d=7,r=21,p=0.012
# 8 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         3 pymatching <1m     984094        2171 d=5,r=15,p=0.009
#         3 pymatching <1m     991262        2691 d=5,r=15,p=0.011
#         2 pymatching <1m     984094         247 d=5,r=15,p=0.012
#         2 pymatching <1m     998703        4813 d=7,r=21,p=0.008
#         2 pymatching <1m     994607        3825 d=7,r=21,p=0.009
#         2 pymatching <1m     992798        3034 d=7,r=21,p=0.01
#         2 pymatching <1m     993822        2967 d=7,r=21,p=0.011
#         2 pymatching <1m     998942        4597 d=7,r=21,p=0.012
# 8 tasks left:
#   workers    decoder        eta shots_left errors_left json_metadata
#         3 pymatching        <1m     981773        1738 d=5,r=15,p=0.009
#         3 pymatching        <1m     988941        2114 d=5,r=15,p=0.011
#         2 pymatching [draining]     982046        -371 d=5,r=15,p=0.012
#         2 pymatching        <1m     998686        4810 d=7,r=21,p=0.008
#         2 pymatching        <1m     994590        3824 d=7,r=21,p=0.009
#         2 pymatching        <1m     992798        3034 d=7,r=21,p=0.01
#         2 pymatching        <1m     993822        2967 d=7,r=21,p=0.011
#         2 pymatching        <1m     998942        4597 d=7,r=21,p=0.012
# 8 tasks left:
#   workers    decoder        eta shots_left errors_left json_metadata
#         3 pymatching        <1m     979725        1381 d=5,r=15,p=0.009
#         3 pymatching        <1m     988941        2114 d=5,r=15,p=0.011
#         2 pymatching [draining]     981022        -667 d=5,r=15,p=0.012
#         2 pymatching        <1m     998430        4762 d=7,r=21,p=0.008
#         2 pymatching        <1m     994334        3780 d=7,r=21,p=0.009
#         2 pymatching        <1m     992286        2909 d=7,r=21,p=0.01
#         2 pymatching        <1m     993310        2789 d=7,r=21,p=0.011
#         2 pymatching        <1m     998430        4413 d=7,r=21,p=0.012
# 7 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         3 pymatching <1m     977677        1012 d=5,r=15,p=0.009
#         3 pymatching <1m     986893        1596 d=5,r=15,p=0.011
#         3 pymatching <1m     998430        4762 d=7,r=21,p=0.008
#         3 pymatching <1m     994334        3780 d=7,r=21,p=0.009
#         2 pymatching <1m     992286        2909 d=7,r=21,p=0.01
#         2 pymatching <1m     993310        2789 d=7,r=21,p=0.011
#         2 pymatching <1m     998430        4413 d=7,r=21,p=0.012
# 7 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         3 pymatching <1m     977677        1012 d=5,r=15,p=0.009
#         3 pymatching <1m     985869        1298 d=5,r=15,p=0.011
#         3 pymatching <1m     998430        4762 d=7,r=21,p=0.008
#         3 pymatching <1m     994334        3780 d=7,r=21,p=0.009
#         2 pymatching <1m     992286        2909 d=7,r=21,p=0.01
#         2 pymatching <1m     993310        2789 d=7,r=21,p=0.011
#         2 pymatching <1m     997918        4214 d=7,r=21,p=0.012
# 7 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         3 pymatching <1m     974605         463 d=5,r=15,p=0.009
#         3 pymatching <1m     982797         488 d=5,r=15,p=0.011
#         3 pymatching <1m     997405        4598 d=7,r=21,p=0.008
#         3 pymatching <1m     993309        3586 d=7,r=21,p=0.009
#         2 pymatching <1m     992286        2909 d=7,r=21,p=0.01
#         2 pymatching <1m     992798        2622 d=7,r=21,p=0.011
#         2 pymatching <1m     997406        4026 d=7,r=21,p=0.012
# 7 tasks left:
#   workers    decoder        eta shots_left errors_left json_metadata
#         3 pymatching [draining]     970509        -247 d=5,r=15,p=0.009
#         3 pymatching        <1m     982797         488 d=5,r=15,p=0.011
#         3 pymatching        <1m     996365        4413 d=7,r=21,p=0.008
#         3 pymatching        <1m     993293        3582 d=7,r=21,p=0.009
#         2 pymatching        <1m     991262        2633 d=7,r=21,p=0.01
#         2 pymatching        <1m     991774        2288 d=7,r=21,p=0.011
#         2 pymatching        <1m     997406        4026 d=7,r=21,p=0.012
# 7 tasks left:
#   workers    decoder        eta shots_left errors_left json_metadata
#         3 pymatching [draining]     969485        -430 d=5,r=15,p=0.009
#         3 pymatching [draining]     980749         -35 d=5,r=15,p=0.011
#         3 pymatching        <1m     996109        4361 d=7,r=21,p=0.008
#         3 pymatching        <1m     993037        3537 d=7,r=21,p=0.009
#         2 pymatching        <1m     991262        2633 d=7,r=21,p=0.01
#         2 pymatching        <1m     991774        2288 d=7,r=21,p=0.011
#         2 pymatching        <1m     997406        4026 d=7,r=21,p=0.012
# 6 tasks left:
#   workers    decoder        eta shots_left errors_left json_metadata
#         3 pymatching [draining]     979725        -305 d=5,r=15,p=0.011
#         3 pymatching        <1m     995085        4187 d=7,r=21,p=0.008
#         3 pymatching        <1m     992013        3346 d=7,r=21,p=0.009
#         3 pymatching        <1m     990238        2374 d=7,r=21,p=0.01
#         3 pymatching        <1m     991774        2288 d=7,r=21,p=0.011
#         3 pymatching        <1m     996894        3848 d=7,r=21,p=0.012
# 5 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         4 pymatching <1m     993549        3910 d=7,r=21,p=0.008
#         4 pymatching <1m     991501        3238 d=7,r=21,p=0.009
#         4 pymatching <1m     990238        2374 d=7,r=21,p=0.01
#         3 pymatching <1m     991774        2288 d=7,r=21,p=0.011
#         3 pymatching <1m     996894        3848 d=7,r=21,p=0.012
# 5 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         4 pymatching <1m     993549        3910 d=7,r=21,p=0.008
#         4 pymatching <1m     990477        3020 d=7,r=21,p=0.009
#         4 pymatching <1m     990238        2374 d=7,r=21,p=0.01
#         3 pymatching <1m     990749        1955 d=7,r=21,p=0.011
#         3 pymatching <1m     996381        3673 d=7,r=21,p=0.012
# 5 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         4 pymatching <1m     993532        3907 d=7,r=21,p=0.008
#         4 pymatching <1m     990477        3020 d=7,r=21,p=0.009
#         4 pymatching <1m     989197        2095 d=7,r=21,p=0.01
#         3 pymatching <1m     990733        1950 d=7,r=21,p=0.011
#         3 pymatching <1m     995853        3478 d=7,r=21,p=0.012
# 5 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         4 pymatching <1m     993532        3907 d=7,r=21,p=0.008
#         4 pymatching <1m     990460        3017 d=7,r=21,p=0.009
#         4 pymatching <1m     988940        2040 d=7,r=21,p=0.01
#         3 pymatching <1m     989709        1599 d=7,r=21,p=0.011
#         3 pymatching <1m     995853        3478 d=7,r=21,p=0.012
# 5 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         4 pymatching <1m     991228        3565 d=7,r=21,p=0.008
#         4 pymatching <1m     989180        2771 d=7,r=21,p=0.009
#         4 pymatching <1m     987916        1788 d=7,r=21,p=0.01
#         3 pymatching <1m     989453        1526 d=7,r=21,p=0.011
#         3 pymatching <1m     995597        3387 d=7,r=21,p=0.012
# 5 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         4 pymatching <1m     990204        3405 d=7,r=21,p=0.008
#         4 pymatching <1m     988156        2553 d=7,r=21,p=0.009
#         4 pymatching <1m     987644        1716 d=7,r=21,p=0.01
#         3 pymatching <1m     989453        1526 d=7,r=21,p=0.011
#         3 pymatching <1m     994573        3001 d=7,r=21,p=0.012
# 5 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         4 pymatching <1m     990204        3405 d=7,r=21,p=0.008
#         4 pymatching <1m     988156        2553 d=7,r=21,p=0.009
#         4 pymatching <1m     987644        1716 d=7,r=21,p=0.01
#         3 pymatching <1m     989453        1526 d=7,r=21,p=0.011
#         3 pymatching <1m     994061        2808 d=7,r=21,p=0.012
# 5 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         4 pymatching <1m     990204        3405 d=7,r=21,p=0.008
#         4 pymatching <1m     987132        2362 d=7,r=21,p=0.009
#         4 pymatching <1m     986108        1296 d=7,r=21,p=0.01
#         3 pymatching <1m     988429        1206 d=7,r=21,p=0.011
#         3 pymatching <1m     994061        2808 d=7,r=21,p=0.012
# 5 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         4 pymatching <1m     988156        3107 d=7,r=21,p=0.008
#         4 pymatching <1m     986108        2150 d=7,r=21,p=0.009
#         4 pymatching <1m     985084        1018 d=7,r=21,p=0.01
#         3 pymatching <1m     987917        1050 d=7,r=21,p=0.011
#         3 pymatching <1m     994061        2808 d=7,r=21,p=0.012
# 5 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         4 pymatching <1m     986108        2796 d=7,r=21,p=0.008
#         4 pymatching <1m     985084        1930 d=7,r=21,p=0.009
#         4 pymatching <1m     985084        1018 d=7,r=21,p=0.01
#         3 pymatching <1m     987917        1050 d=7,r=21,p=0.011
#         3 pymatching <1m     993037        2419 d=7,r=21,p=0.012
# 5 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         4 pymatching <1m     986108        2796 d=7,r=21,p=0.008
#         4 pymatching <1m     984060        1704 d=7,r=21,p=0.009
#         4 pymatching <1m     985084        1018 d=7,r=21,p=0.01
#         3 pymatching <1m     986893         720 d=7,r=21,p=0.011
#         3 pymatching <1m     993037        2419 d=7,r=21,p=0.012
# 5 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         4 pymatching <1m     986108        2796 d=7,r=21,p=0.008
#         4 pymatching <1m     983036        1491 d=7,r=21,p=0.009
#         4 pymatching <1m     984060         766 d=7,r=21,p=0.01
#         3 pymatching <1m     986381         563 d=7,r=21,p=0.011
#         3 pymatching <1m     992525        2229 d=7,r=21,p=0.012
# 5 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         4 pymatching <1m     986108        2796 d=7,r=21,p=0.008
#         4 pymatching <1m     983036        1491 d=7,r=21,p=0.009
#         4 pymatching <1m     983036         509 d=7,r=21,p=0.01
#         3 pymatching <1m     986381         563 d=7,r=21,p=0.011
#         3 pymatching <1m     992013        2049 d=7,r=21,p=0.012
# 5 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         4 pymatching <1m     983036        2320 d=7,r=21,p=0.008
#         4 pymatching <1m     982012        1284 d=7,r=21,p=0.009
#         4 pymatching <1m     983036         509 d=7,r=21,p=0.01
#         3 pymatching <1m     986381         563 d=7,r=21,p=0.011
#         3 pymatching <1m     991501        1855 d=7,r=21,p=0.012
# 5 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         4 pymatching <1m     982012        2171 d=7,r=21,p=0.008
#         4 pymatching <1m     982012        1284 d=7,r=21,p=0.009
#         4 pymatching <1m     982012         240 d=7,r=21,p=0.01
#         3 pymatching <1m     986381         563 d=7,r=21,p=0.011
#         3 pymatching <1m     991501        1855 d=7,r=21,p=0.012
# 5 tasks left:
#   workers    decoder        eta shots_left errors_left json_metadata
#         4 pymatching        <1m     982012        2171 d=7,r=21,p=0.008
#         4 pymatching        <1m     980988        1071 d=7,r=21,p=0.009
#         4 pymatching [draining]     980988         -26 d=7,r=21,p=0.01
#         3 pymatching        <1m     985357         210 d=7,r=21,p=0.011
#         3 pymatching        <1m     991501        1855 d=7,r=21,p=0.012
# 5 tasks left:
#   workers    decoder        eta shots_left errors_left json_metadata
#         4 pymatching        <1m     982012        2171 d=7,r=21,p=0.008
#         4 pymatching        <1m     978940         608 d=7,r=21,p=0.009
#         4 pymatching [draining]     980988         -26 d=7,r=21,p=0.01
#         3 pymatching        <1m     984845          58 d=7,r=21,p=0.011
#         3 pymatching        <1m     990989        1650 d=7,r=21,p=0.012
# 5 tasks left:
#   workers    decoder        eta shots_left errors_left json_metadata
#         4 pymatching        <1m     980988        2027 d=7,r=21,p=0.008
#         4 pymatching        <1m     978940         608 d=7,r=21,p=0.009
#         4 pymatching [draining]     980988         -26 d=7,r=21,p=0.01
#         3 pymatching [draining]     983821        -277 d=7,r=21,p=0.011
#         3 pymatching        <1m     990477        1452 d=7,r=21,p=0.012
# 5 tasks left:
#   workers    decoder        eta shots_left errors_left json_metadata
#         4 pymatching        <1m     978940        1697 d=7,r=21,p=0.008
#         4 pymatching        <1m     978940         608 d=7,r=21,p=0.009
#         4 pymatching [draining]     979964        -310 d=7,r=21,p=0.01
#         3 pymatching [draining]     983821        -277 d=7,r=21,p=0.011
#         3 pymatching        <1m     989965        1269 d=7,r=21,p=0.012
# 5 tasks left:
#   workers    decoder        eta shots_left errors_left json_metadata
#         4 pymatching        <1m     977916        1547 d=7,r=21,p=0.008
#         4 pymatching        <1m     976892         181 d=7,r=21,p=0.009
#         4 pymatching [draining]     978940        -595 d=7,r=21,p=0.01
#         3 pymatching [draining]     983309        -458 d=7,r=21,p=0.011
#         3 pymatching        <1m     989965        1269 d=7,r=21,p=0.012
# 5 tasks left:
#   workers    decoder        eta shots_left errors_left json_metadata
#         4 pymatching        <1m     977916        1547 d=7,r=21,p=0.008
#         4 pymatching [draining]     975868         -28 d=7,r=21,p=0.009
#         4 pymatching [draining]     977916        -905 d=7,r=21,p=0.01
#         3 pymatching [draining]     982285        -784 d=7,r=21,p=0.011
#         3 pymatching        <1m     988941         902 d=7,r=21,p=0.012
# 4 tasks left:
#   workers    decoder        eta shots_left errors_left json_metadata
#         6 pymatching        <1m     974844        1085 d=7,r=21,p=0.008
#         4 pymatching [draining]     974844        -241 d=7,r=21,p=0.009
#         3 pymatching [draining]     982285        -784 d=7,r=21,p=0.011
#         5 pymatching        <1m     988941         902 d=7,r=21,p=0.012
# 4 tasks left:
#   workers    decoder        eta shots_left errors_left json_metadata
#         6 pymatching        <1m     974844        1085 d=7,r=21,p=0.008
#         4 pymatching [draining]     974844        -241 d=7,r=21,p=0.009
#         3 pymatching [draining]     981261       -1115 d=7,r=21,p=0.011
#         5 pymatching        <1m     988941         902 d=7,r=21,p=0.012
# 3 tasks left:
#   workers    decoder        eta shots_left errors_left json_metadata
#         7 pymatching        <1m     973802         933 d=7,r=21,p=0.008
#         4 pymatching [draining]     973820        -450 d=7,r=21,p=0.009
#         7 pymatching        <1m     988411         720 d=7,r=21,p=0.012
# 3 tasks left:
#   workers    decoder        eta shots_left errors_left json_metadata
#         7 pymatching        <1m     973257         849 d=7,r=21,p=0.008
#         4 pymatching [draining]     972796        -691 d=7,r=21,p=0.009
#         7 pymatching        <1m     987387         314 d=7,r=21,p=0.012
# 2 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         9 pymatching <1m     969929         294 d=7,r=21,p=0.008
#         9 pymatching <1m     986825         108 d=7,r=21,p=0.012
# 2 tasks left:
#   workers    decoder        eta shots_left errors_left json_metadata
#         9 pymatching        <1m     969929         294 d=7,r=21,p=0.008
#         9 pymatching [draining]     986057        -169 d=7,r=21,p=0.012
# 2 tasks left:
#   workers    decoder        eta shots_left errors_left json_metadata
#         9 pymatching        <1m     968871         118 d=7,r=21,p=0.008
#         9 pymatching [draining]     985801        -266 d=7,r=21,p=0.012
# 2 tasks left:
#   workers    decoder        eta shots_left errors_left json_metadata
#         9 pymatching [draining]     967335        -127 d=7,r=21,p=0.008
#         9 pymatching [draining]     985289        -446 d=7,r=21,p=0.012
# 2 tasks left:
#   workers    decoder        eta shots_left errors_left json_metadata
#         9 pymatching [draining]     962215        -929 d=7,r=21,p=0.008
#         9 pymatching [draining]     982729       -1433 d=7,r=21,p=0.012
# 2 tasks left:
#   workers    decoder        eta shots_left errors_left json_metadata
#         9 pymatching [draining]     960167       -1267 d=7,r=21,p=0.008
#         9 pymatching [draining]     981193       -2031 d=7,r=21,p=0.012
# 2 tasks left:
#   workers    decoder        eta shots_left errors_left json_metadata
#         9 pymatching [draining]     957095       -1768 d=7,r=21,p=0.008
#         9 pymatching [draining]     980169       -2384 d=7,r=21,p=0.012
# 1 tasks left:
#   workers    decoder        eta shots_left errors_left json_metadata
#         9 pymatching [draining]     979145       -2752 d=7,r=21,p=0.012
# 1 tasks left:
#   workers    decoder        eta shots_left errors_left json_metadata
#         9 pymatching [draining]     978121       -3146 d=7,r=21,p=0.012

# %%
fig, ax = plt.subplots(1, 1)
sinter.plot_error_rate(
    ax=ax,
    stats=collected_surface_code_stats,
    x_func=lambda stat: stat.json_metadata['p'],
    group_func=lambda stat: stat.json_metadata['d'],
    failure_units_per_shot_func=lambda stat: stat.json_metadata['r'],
)
ax.set_ylim(5e-3, 5e-2)
ax.set_xlim(0.008, 0.012)
ax.loglog()
ax.set_title("Surface Code Error Rates per Round under Circuit Noise")
ax.set_xlabel("Phyical Error Rate")
ax.set_ylabel("Logical Error Rate per Round")
ax.grid(which='major')
ax.grid(which='minor')
ax.legend()
fig.set_dpi(120)  # Show it bigger

# %% [markdown]
# # fusion_blossom

# %%
import os

surface_code_tasks = [
    sinter.Task(
        circuit = stim.Circuit.generated(
            "surface_code:rotated_memory_z",
            rounds=d * 3,
            distance=d,
            after_clifford_depolarization=noise,
            after_reset_flip_probability=noise,
            before_measure_flip_probability=noise,
            before_round_data_depolarization=noise,
        ),
        json_metadata={'d': d, 'r': d * 3, 'p': noise},
    )
    for d in [3, 5, 7]
    for noise in [0.008, 0.009, 0.01, 0.011, 0.012]
]

collected_surface_code_stats: List[sinter.TaskStats] = sinter.collect(
    num_workers=os.cpu_count(),    #这句代码会占用所有CPU，可以改成 num_workers = max(1, os.cpu_count() // 2)
    tasks=surface_code_tasks,
    decoders=['fusion_blossom'],
    max_shots=1_000_000,
    max_errors=5_000,
)

# %%
fig, ax = plt.subplots(1, 1)
sinter.plot_error_rate(
    ax=ax,
    stats=collected_surface_code_stats,
    x_func=lambda stat: stat.json_metadata['p'],
    group_func=lambda stat: stat.json_metadata['d'],
    failure_units_per_shot_func=lambda stat: stat.json_metadata['r'],
)
ax.set_ylim(5e-3, 5e-2)
ax.set_xlim(0.008, 0.012)
ax.loglog()
ax.set_title("Surface Code Error Rates per Round under Circuit Noise")
ax.set_xlabel("Phyical Error Rate")
ax.set_ylabel("Logical Error Rate per Round")
ax.grid(which='major')
ax.grid(which='minor')
ax.legend()
fig.set_dpi(120)  # Show it bigger
